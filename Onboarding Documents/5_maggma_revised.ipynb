# %% [markdown]
# # Joint Undergraduate Researcher Onboarding #5
# **Topic:** Introduction to maggma to ease working with MongoDB databases
#
# **Date:** April 4, 2022
#
# **Prepared by:** Ann Rutt

# %% [markdown]
# # Outline & Relevant Documentation
#
# Onboarding Session Demonstration:
# * Getting Stores: Connecting to your Database
# * Store `key` Attribute: Specify field for distinguishing documents
# * Store `query_one()` and `query()` Method: Accessing database docs
# * Store `update()` Method: Storing database docs
# * Store `count()` Method
# * Store `distinct()` Method: Get distinct values of specified field
# * Store `remove_docs()` Method
# * Getting a Builder
# * Builder `get_items()` Method
# * Builder `process_item()` Method
# * Builder `update_target()` Method
# * Running a Builder for Testing: `run()` Method
# * Writing a Custom Builder
#
# Onboarding Independent Exercises Goals:
# * Become familiar with the ApproxNEB data stored in `fw_acr_mv/approx_neb`
# * Apply MongoDB querying and learn about more advanced querying techniques (https://docs.mongodb.com/manual/reference/operator/query/)
# * Practice using common store methods (`query`, `count`, `distinct`)
# * Try out developing and testing a builder by creating a custom MapBuilder
#
# For further reading and general reference...
# * Maggma Documentation: https://materialsproject.github.io/maggma/
# * Maggma GitHub Repo: https://github.com/materialsproject/maggma

# %% [markdown]
# # Set-up Check: Mongogrant Credentials
#
# Run the code in this section on your own before the onboarding session to see if everything is working correctly with your `.mongogrant.json` file which should be located in your home directory.
#
# **You need to be connected to the LBL VPN to successfully run this code.**

# %%
from maggma.stores.advanced_stores import MongograntStore
aneb_store = MongograntStore("ro:mongodb07-ext.nersc.gov/fw_acr_mv","approx_neb")
aneb_store.connect()
aneb_store.query_one({})
# Out:
# /Users/tashalewis/miniconda3/envs/torl/lib/python3.9/site-packages/maggma/utils.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# {'_id': ObjectId('5dbcecc3343e0926a3317022'),
#  'last_updated': datetime.datetime(2016, 9, 21, 17, 1, 33, 101000),
#  'host': {'dir_name': 'nid02991:/global/projecta/projectdirs/matgen/acrutt/block_2019-08-18-15-46-52-604494/launcher_2019-11-02-00-05-37-192454',
#   'formula_pretty': 'FePO4',
#   'input_structure': {'@module': 'pymatgen.core.structure',
#    '@class': 'Structure',
#    'charge': None,
#    'lattice': {'matrix': [[10.007105, 8.8e-05, 6.5e-05],
#      [0.000104, 11.868464, -0.000266],
#      [6.4e-05, -0.00022, 9.786512]],
#     'a': 10.007105000598,
#     'b': 11.8684640034365,
#     'c': 9.78651200268206,
#     'alpha': 90.0025721334633,
#     'beta': 89.99925316096,
#     'gamma': 89.9989940967199,
#     'volume': 1162.33390474949},
#    'sites': [{'species': [{'element': 'Fe', 'occu': 1}],
#      'abc': [0.775093, 0.124994, 0.26611],
#      'xyz': [7.756467066181, 1.4834964532, 2.604305840961],
#      'label': 'Fe',
#      'properties': {}},
#     {'species': [{'element': 'Fe', 'occu': 1}],
#      'abc': [0.775093, 0.124994, 0.76611],
#      'xyz': [7.756499066181, 1.4833864532, 7.497561840961],
#      'label': 'Fe',
#      'properties': {}},
#     {'species': [{'element': 'Fe', 'occu': 1}],
#      'abc': [0.775093, 0.624994, 0.266109],
#      'xyz': [7.756519066117, 7.41772845342, 2.604163054449],
#      'label': 'Fe',
#      'properties': {}},
#     {'species': [{'element': 'Fe', 'occu': 1}],
#      'abc': [0.775093, 0.624994, 0.76611],
#      'xyz': [7.756551066181, 7.4176184532, 7.497428840961],
#      'label': 'Fe',
#      'properties': {}},
#     {'species': [{'element': 'Fe', 'occu': 1}],
#      'abc': [0.724918, 0.374997, 0.016133],
#      'xyz': [7.25437057459, 4.450698638132, 0.157833168564],
#      'label': 'Fe',
#      'properties': {}},
#     {'species': [{'element': 'Fe', 'occu': 1}],
#      'abc': [0.724918, 0.374997, 0.516134],
#      'xyz': [7.254402574654, 4.450588637912, 5.051098955076],
#      'label': 'Fe',
#      'properties': {}},
#     {'species': [{'element': 'Fe', 'occu': 1}],
#      'abc': [0

#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.672179, 0.225946, 0.614735],
#      'xyz': [6.726628673219, 2.681555876996, 6.016095044319],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.672179, 0.725946, 0.114735],
#      'xyz': [6.726648673219, 8.615897876996, 1.122706044319],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.672179, 0.725946, 0.614735],
#      'xyz': [6.726680673219, 8.615787876996, 6.015962044319],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.377603, 0.374999, 0.112601],
#      'xyz': [3.778759075675, 4.45067058838, 1.101895832173],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.377603, 0.374999, 0.612601],
#      'xyz': [3.778791075675, 4.45056058838, 5.995151832173],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.377603, 0.874999, 0.112601],
#      'xyz': [3.778811075675, 10.38490258838, 1.101762832173],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.377603, 0.874999, 0.612601],
#      'xyz': [3.778843075675, 10.38479258838, 5.995018832173],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.44879, 0.124999, 0.072627],
#      'xyz': [4.491106300974, 1.483569647116, 0.71076092864],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.44879, 0.124999, 0.572627],
#      'xyz': [4.491138300974, 1.483459647116, 5.60401692864],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.44879, 0.624999, 0.072627],
#      'xyz': [4.491158300974, 7.417801647116, 0.71062792864],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.44879, 0.624999, 0.572627],
#      'xyz': [4.491190300974, 7.417691647116, 5.60388392864],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.948804, 0.124998, 0.177371],
#      'xyz': [9.494805603956, 1.483578736204, 1.735871842744],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.948804, 0.124998, 0.67737],
#      'xyz': [9.494837603892, 1.483468736424, 6.629118056232],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.948804, 0.624998, 0.17737],
#      'xyz': [9.494857603892, 7.417810736424, 1.735729056232],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.948804, 0.624997, 0.677371],
#      'xyz': [9.494889603852, 7.41768886774, 6.62899484301],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.622394, 0.124997, 0.387394],
#      'xyz': [6.228399902274, 1.4834919386, 3.791243236136],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.622394, 0.124997, 0.887393],
#      'xyz': [6.22843190221, 1.48338193882, 8.684489449624],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.622394, 0.624997, 0.387394],
#      'xyz': [6.228451902274, 7.4177239386, 3.791110236136],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.622394, 0.624998, 0.887394],
#      'xyz': [6.228483902378, 7.417625807064, 8.68436623587],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.672186, 0.024052, 0.114741],
#      'xyz': [6.726645726362, 0.285494205476, 1.12295146765],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.672186, 0.024052, 0.614741],
#      'xyz': [6.726677726362, 0.285384205476, 6.01620746765],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.672186, 0.524052, 0.114741],
#      'xyz': [6.726697726362, 6.219726205476, 1.12281846765],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.672186, 0.524052, 0.614741],
#      'xyz': [6.726729726362, 6.219616205476, 6.01607446765],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.327824, 0.475942, 0.385269],
#      'xyz': [3.280643344704, 5.64864458242, 3.770334399716],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.327824, 0.475942, 0.885269],
#      'xyz': [3.280675344704, 5.64853458242, 8.663590399716],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.327824, 0.975942, 0.385269],
#      'xyz': [3.280695344704, 11.58287658242, 3.770201399716],
#      'label': 'O',
#      'properties': {}},
#     {'species': [{'element': 'O', 'occu': 1}],
#      'abc': [0.327824, 0.975942, 0.885269],
#      'xyz': [3.280727344704, 11.58276658242, 8.663457399716],
#      'label': 'O',
#      'properties': {}}]},
#   'output': {'structure': {'@module': 'pymatgen.core.structure',
#     '@class': 'Structure',
#     'charge': None,
#     'lattice': {'matrix': [[9.99795997, -5.394e-05, 8.267e-05],
#       [-6.445e-05, 11.9617621, -9.293e-05],
#       [8.087e-05, -7.74e-05, 9.80554349]],
#      'a': 9.99795997048729,
#      'b': 11.9617621005346,
#      'c': 9.80554349063896,
#      'alpha': 90.000897392903,
#      'beta': 89.999053696889,
#      'gamma': 90.0006178299596,
#      'volume': 1172.676506361},
#     'sites': [{'species': [{'element': 'Fe', 'occu': 1}],
#       'abc': [0

#       'label': 'O',
#       'properties': {'magmom': 0.164}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.44832743, 0.62499167, 0.57180833],
#       'xyz': [4.48236566001949, 7.47593323027539, 5.60687043051202],
#       'label': 'O',
#       'properties': {'magmom': 0.164}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.94836802, 0.12498864, 0.17820133],
#       'xyz': [9.48175185641187, 1.4950194291286, 1.74742767768074],
#       'label': 'O',
#       'properties': {'magmom': 0.163}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.94836802, 0.12498864, 0.67820033],
#       'xyz': [9.481792291331, 1.494980729206, 6.65018961713725],
#       'label': 'O',
#       'properties': {'magmom': 0.163}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.94836802, 0.62498864, 0.17820033],
#       'xyz': [9.481719631331, 7.475900479206, 1.74737140713725],
#       'label': 'O',
#       'properties': {'magmom': 0.163}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.94836802, 0.62498764, 0.67820133],
#       'xyz': [9.48176006647632, 7.4758498173665, 6.65015295777367],
#       'label': 'O',
#       'properties': {'magmom': 0.163}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.62354429, 0.12498776, 0.38770348],
#       'xyz': [6.23419414906137, 1.49501020830354, 3.80168326765826],
#       'label': 'O',
#       'properties': {'magmom': 0.156}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.62354429, 0.12498776, 0.88770248],
#       'xyz': [6.2342345839805, 1.49497150838094, 8.70444520711477],
#       'label': 'O',
#       'properties': {'magmom': 0.156}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.62354429, 0.62498776, 0.38770348],
#       'xyz': [6.23416192406137, 7.47589125830354, 3.80163680265826],
#       'label': 'O',
#       'properties': {'magmom': 0.156}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.62354429, 0.62498876, 0.88770348],
#       'xyz': [6.23420235899692, 7.47586452006564, 8.70440854756533],
#       'label': 'O',
#       'properties': {'magmom': 0.156}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.67132458, 0.02440692, 0.11435787],
#       'xyz': [6.71188395281202, 0.291904708086749, 1.12139429797672],
#       'label': 'O',
#       'properties': {'magmom': 0.189}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.67132458, 0.02440692, 0.61435787],
#       'xyz': [6.71192438781202, 0.291866008086749, 6.02416604297672],
#       'label': 'O',
#       'properties': {'magmom': 0.189}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.67132458, 0.52440692, 0.11435787],
#       'xyz': [6.71185172781202, 6.27278575808675, 1.12134783297672],
#       'label': 'O',
#       'properties': {'magmom': 0.189}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.67132458, 0.52440692, 0.61435787],
#       'xyz': [6.71189216281202, 6.27274705808675, 6.02411957797672],
#       'label': 'O',
#       'properties': {'magmom': 0.189}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.32867194, 0.47560193, 0.38564296],
#       'xyz': [3.28604943378403, 5.6889895636313, 3.78142178951426],
#       'label': 'O',
#       'properties': {'magmom': 0.189}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.32867194, 0.47560193, 0.88564296],
#       'xyz': [3.28608986878403, 5.6889508636313, 8.68419353451426],
#       'label': 'O',
#       'properties': {'magmom': 0.189}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.32867194, 0.97560193, 0.38564296],
#       'xyz': [3.28601720878403, 11.6698706136313, 3.78137532451426],
#       'label': 'O',
#       'properties': {'magmom': 0.189}},
#      {'species': [{'element': 'O', 'occu': 1}],
#       'abc': [0.32867194, 0.97560193, 0.88564296],
#       'xyz': [3.28605764378403, 11.6698319136313, 8.68414706951426],
#       'label': 'O',
#       'properties': {'magmom': 0.189}}]},
#    'density': 3.41695539205663,
#    'energy': -710.87029876,
#    'energy_per_atom': -7.40489894541667,
#    'forces': [[-0.00209235, -5.206e-05, 0.00644474],
#     [-0.00209235, -5.206e-05, 0.00644474],
#     [-0.00209235, -5.206e-05, 0.00644474],
#     [-0.00209235, -5.206e-05, 0.00644474],
#     [0.00165147, 2.459e-05, 0.00820258],
#     [0.00165147, 2.459e-05, 0.00820258],
#     [0.00165147, 2.459e-05, 0.00820258],
#     [0.00165147, 2.459e-05, 0.00820258],
#     [-0.00254299, -4.134e-05, -0.00685008],
#     [-0.00254299, -4.134e-05, -0.00685008],
#     [-0.00254299, -4.134e-05, -0.00685008],
#     [-0.00254299, -4.134e-05, -0.00685008],
#     [0.00345548, -0.00014088, -0.00773431],
#     [0.00345548, -0.00014088, -0.00773431],
#     [0.00345548, -0.00014088, -0.00773431],
#     [0.00345548, -0.00014088, -0.00773431],
#     [0.01168137, 0.00050392, 0.02161452],
#     [-0.01680251, -0.00051772, 0.03694114],
#     [-0.01680251, -0.00051772, 0.03694114],
#     [-0.01680251, -0.00051772, 0.03694114],
#     [0.03425562, -0.00090434, -2.974e-05],
#     [0.03425562, -0.00090434, -2.974e-05],
#     [0.03425562, -0.00090434, -2.974e-05],
#     [0.03425562, -0.00090434, -2.974e-05],
#     [-0.00406249, -0.00678514, 0.01163725],
#     [-0.00406249, -0.00678514, 0.01163725],
#     [-0.00406249, -0.00678514, 0.01163725],
#     [-0.00406249, -0.00678514, 0.01163725],
#     [0.00336072, 0.00187849, -0.00977773],
#     [0.00336072, 0.00187849, -0.00977773],
#     [0.00336072, 0.00187849, -0.00977773],
#     [0.00336072, 0.00187849, -0.00977773]],
#    'stress': [[0.01649236, -0.00119066, -0.00228931],
#     [-0.00119247, 2.12276574, 0.00552312],
#     [-0.00229324, 0.00552405, 1.97218084]],
#    'bandgap': 0.6734,
#    'cbm': 2.364,
#    'vbm': 1.6906,
#    'is_gap_direct': True,
#    'is_metal': False,
#    'spacegroup': {'source': 'spglib',
#     'symbol': 'Pnma',
#     'number': 62,
#     'point_group': 'mmm',
#     'crystal_system': 'orthorhombic',
#     'hall': '-P 2ac 2n'}},
#   'task_id': 2476},
#  'wf_uuid': 'f720ba2f-be68-407f-a447-fc2ed7a20948',
#  'end_points': [{'input_structure': {'@module': 'pymatgen.core.structure',
#     '@class': 'Structure',
#     'charge': None,
#     'lattice': {'matrix': [[9.99795997, -5.394e-05, 8.267e-05],
#       [-6.445e-05, 11.9617621, -9.293e-05],
#       [8.087e-05, -7.74e-05, 9.80554349]],
#      'a': 9.99795997048729,
#      'b': 11.9617621005346,
#      'c': 9.80554349063896,
#      'alpha': 90.000897392903,
#      'beta': 89.999053696889,
#      'gamma': 90.0006178299596,
#      'volume': 1172.676506361},
#     'sites': [{'species': [{'element': 'Mg', 'occu': 1}],
#       'abc': [0.0, 0.0, 0.0],
#       'xyz': [0.0, 0.0, 0.0],
#       'label': 'Mg',
#       'properties': {}},
#      {'species': [{'element': 'Fe', 'occu': 1}],
#       'abc': [0.77499818, 0.1249948, 0.26626939],
#       'xyz': [7.74841425775356, 1.49509564868446, 2.61096853703355],
#       'label': 'Fe',
#       'properties': {}},
#      {'species': [{'element': 'Fe', 'occu': 1}],
#       'abc': [0.77499818, 0.1249948, 0.76626939],
#       'xyz': [7.74845469275356, 1.49505694868446, 7.51374028203355],
#       'label': 'Fe',
#       'properties': {}},
# ...
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.16762653, 0.51975517, 0.13550161],
#         'xyz': [1.67590105317833, 6.21716815635295, 1.32863243919541],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.174}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.15115359, 0.51021314, 0.62420301],
#         'xyz': [1.51124545347925, 6.10299192402705, 6.12061455121038],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.113}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.16765532, 0.23024031, 0.13553374],
#         'xyz': [1.6762074260003, 2.75406030154096, 1.32897441856355],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.174}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.15248168, 0.23835777, 0.6246715],
#         'xyz': [1.52454108086702, 2.85112258187452, 6.12523374283133],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.112}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.17064843, 0.72201913, 0.1314842],
#         'xyz': [1.70610061819868, 8.63660165320844, 1.2892209929612],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.181}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.17598887, 0.71461279, 0.63068115],
#         'xyz': [1.75953503265979, 8.54797005028845, 6.18411928370119],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0
},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.67176347, 0.5242012, 0.11557865],
#         'xyz': [6.71624011551505, 6.27032481973097, 1.13331842811336],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.182}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.66957986, 0.52225109, 0.61463211],
#         'xyz': [6.69444901821675, 6.24695975883567, 6.02680858956274],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.178}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.32156755, 0.47516233, 0.38772948],
#         'xyz': [3.21502049789676, 5.6837314830078, 3.8018805885176],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.168}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.33625076, 0.47566538, 0.89337855],
#         'xyz': [3.36186356952783, 5.68970911951017, 8.76004545923539],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.18}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.33078436, 0.97536851, 0.38029306],
#         'xyz': [3.30713718005882, 11.6670788339936, 3.72891669826203],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.188}},
#        {'species': [{'element': 'O', 'occu': 1}],
#         'abc': [0.32932568, 0.97566742, 0.88268356],
#         'xyz': [3.29259403026628, 11.6706157189732, 8.65512819993446],
#         'label': 'O',
#         'properties': {'selective_dynamics': [True, True, True],
#          'magmom': 0.186}}]},
#      'density': 3.4513720662988,
#      'energy': -716.69483599,
#      'energy_per_atom': -7.38860655659794,
#      'forces': [[0.15524621, 0.08394427, 0.11338447],
#       [0.00095253, 0.00202828, 0.00885778],
#       [0.00114485, 0.00157103, 0.00802944],
#       [0.00049574, -0.00124086, 0.00792696],
#       [-0.00114722, -0.0024814, 0.00843147],
#       [-0.00252831, -9.955e-05, 0.01419253],
#       [-0.00495498, -0.00112713, 0.0167639],
#       [-5.719e-05, 0.0003164, 0.00318472],
#       [-0.00386314, 2.289e-05, 0.00431156],
#       [-0.00152731, -0.00688521, -0.01351091],
#       [0.00227334, -0.00408675, -0.01224937],
#       [0.00170534, 0.00874468, -0.01910068],
#       [0.00318091, 0.0029782, -0.01462495],
#       [-0.00390319, 0.0001434, -0.00073445],
#       [-0.00814936, -0.00317469, 0.00515104],
#       [-0.00697262, 0.00050799, -0.01853779],
#       [-0.00189331, -0.0027652, -0.01617227],
#       [-0.00436232, 0.00592901, -0.01490282],
#       [-0.00013769, 0.01144293, -0.008963],
#       [-0.00525153, -0.00618828, -0.01932254],
#       [-0.00483703, -0.00684745, -0.01006035],
#       [-0.01073755, -0.00194274, 0.01311619],
#       [-0.0021075, -0.00198901, 0.00086172],
#       [0.00079555, -0.00064239, -0.0226715],
#       [-0.00057781, 0.00027931, -0.01662196],
#       [-0.0002751, -0.00340404, 0.00822531],
#       [-0.00262326, 0.00079524, 0.00693425],
#       [-0.00301174, 0.00295277, 0.00875388],
#       [-0.00243485, -0.00063299, 0.00577996],
#       [-0.00542546, -0.00300882, 0.00668839],
#       [-0.00127337, -0.00460975, 0.01175367],
#       [0.00089436, 0.00035025, 0.0034633],
#       [0.00535953, -0.00071514, 0.00327014],
#       [-0.00584242, -0.00154339, 0.012171],
#       [0.00378773, -0.00198183, 0.00289494],
#       [0.00547636, -0.00084798, -0.00912967],
#       [0.04393743, -0.0009347, -0.02195041],
#       [-0.01114451, -0.00035125, 0.01103728],
#       [0.00500927, -0.00275333, 0.00926912],
#       [0.00183462, 2.305e-05, 0.00491679],
#       [-0.00536174, -0.00049687, -0.0029433],
#       [-0.00557287, 0.00487054, 0.01664827],
#       [-0.00189325, 0.00461052, 0.00954637],
#       [0.00555436, 0.00025831, 0.00457546],
#       [0.00804965, 0.00102235, 0.0056684],
#       [-0.0033493, -0.00089215, 0.01469266],
#       [-0.0033269, -0.00686594, 0.0104894],
#       [0.00508868, -0.0007111, 0.00496865],
#       [0.00484205, -0.00285062, 0.00556596],
#       [-0.00333358, 0.00218836, 0.00518559],
#       [0.00039865, -0.00629026, 0.02540681],
#       [0.00346955, -0.00066701, -0.00370346],
#       [-0.00386915, -0.00438987, -0.01039429],
#       [-0.00073211, -0.00419836, -0.01051081],
#       [0.00637366, -0.0007372, -0.00341837],
#       [0.00025024, 0.00368932, -0.01391632],
#       [0.00263394, -0.01223482, -0.01665294],
#       [-0.00842155, 0.00592161, -0.01792885],
#       [0.00015053, 0.001615, -0.01789417],
#       [-0.00611235, -0.00674232, -0.00850325],
#       [-0.0122588, -0.02015649, -0.00625861],
#       [-0.00593277, 0.00681615, -0.00628777],
#       [-0.00743899, 0.00668845, -0.00121089],
#       [-0.01066044, -0.00576671, -0.02266891],
#       [-0.00279428, -0.01750549, -0.0155553],
#       [-0.0040779, 0.00641212, 0.00602512],
#       [0.00299177, 0.00053965, 0.00316721],
#       [0.00568953, -0.00454635, -0.02874832],
#       [0.00423507, -0.00276854, -0.01823952],
#       [-0.00613809, -0.00230469, 0.01051022],
#       [-0.00869232, -0.00304933, 0.01166695],
#       [-0.00168068, 0.00679718, 0.00887803],
#       [-0.00564817, 0.00571081, 0.00961637],
#       [-0.00264469, -0.00038743, 0.00717264],
#       [-0.00860916, 0.00342002, -0.00071104],
#       [-0.01290574, -0.00107395, -0.01854305],
#       [-0.00658648, -0.0050264, -0.0326666],
#       [-0.00414207, -0.00711806, 0.00317972],
#       [-0.00934519, -0.0055294, -0.00210337],
#       [-0.00571444, 0.00785199, 0.00259741],
#       [-0.01020378, 0.00397043, -0.00226735],
#       [-0.00574515, 0.00781907, -0.00542604],
#       [-0.00664673, -0.00081825, 0.00300217],
#       [-0.00628553, -0.00709935, -0.00792414],
#       [0.00060071, -0.00221171, 0.00140512],
#       [0.00257133, -0.00232058, 0.0056046],
#       [0.00257099, -0.00422186, 0.00741813],
#       [0.00178065, 0.00230901, 0.00562917],
#       [0.0025265, 0.00295401, 0.00531405],
#       [-0.00149418, -0.00613387, 0.0088858],
#       [-0.00496281, -0.00657759, 0.00929914],
#       [-0.00625811, 0.00126479, 0.01041799],
#       [-0.00756935, 0.00166779, 0.0097407],
#       [-0.00309547, -0.00115519, 0.00182722],
#       [0.00434409, -0.00067064, 0.00123106],
#       [0.00329599, 0.0027539, -0.02400925],
#       [0.0050312, 0.00059117, -0.0176676]],
#      'stress': [[9.96674726, -0.13551851, 1.47324946],
#       [-0.13551808, 1.96668339, -0.27828169],
#       [1.47324959, -0.27827757, 10.13893994]],
#      'bandgap': 0.0332999999999997,
#      'cbm': 2.6872,
#      'vbm': 2.6539,
#      'is_gap_direct': False,
#      'is_metal': False,
#      'direct_gap': 0.0341999999999998,
#      'spacegroup': {'source': 'spglib',
#       'symbol': 'Pm',
#       'number': 6,
#       'point_group': 'm',
#       'crystal_system': 'monoclinic',
#       'hall': 'P -2y'}},
#     'task_id': 2515}]}}

# %% [markdown]
# The expected output is a long doc print-out. Reach out for help if you run into any errors or issues here so we can troubleshoot individually.

# %% [markdown]
# # Onboarding Session Demonstration

# %% [markdown]
# If maggma has not been installed yet, run this command in terminal
#
# `pip install maggma`

# %%
# maggma is more frequently updated so it is important to check the version you are using
import maggma
print(maggma.__version__)
print(maggma.__path__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 # maggma is more frequently updated so it is important to check the version you are using
# ----> 2 import maggma
#       3 print(maggma.__version__)
#       4 print(maggma.__path__)
#
# ModuleNotFoundError: No module named 'maggma'

# %%
# pprint (pretty print) can be helpful for making dictionaries more readable when printed 
from pprint import pprint

# %% [markdown]
# We will be using database credentials stored in .mongogrant.json to give you read-only access to Ann's database hosted on NERSC so you can practice working with relevant data.
#
#
# **Place a copy of the provided .mongogrant.json file in your home directory**

# %% [markdown]
# ## Store Basics

# %% [markdown]
# ### Getting Stores: Connecting to your Database

# %% [markdown]
# A `MongoStore` object connects to your local MongoDB database

# %%
from maggma.stores.mongolike import MongoStore

# %%
sandbox_store = MongoStore(database= "local_dev",collection_name= "sandbox")
sandbox_store.connect()

# %% [markdown]
# A `MongograntStore` object connects to MongoDB databases (typically hosted on NERSC) with credentials stored in your `.mongogrant` file

# %%
from maggma.stores.advanced_stores import MongograntStore

# %%
aneb_store = MongograntStore("ro:mongodb07-ext.nersc.gov/fw_acr_mv","approx_neb") # note ro: specifies read-only access vs. rw: for read-write access
aneb_store.connect()

# %% [markdown]
# Advanced Tip: A `ConcatStore` can be used to combine multiple databases into a single store object

# %%
from maggma.stores.compound_stores import ConcatStore

# %%
combined_store = ConcatStore([store_1,store_2...])

# %% [markdown]
# ### Store `key` Attribute: Specify field for distinguishing documents

# %% [markdown]
# ### Store `query_one()` and `query()` Method: Accessing database docs

# %% [markdown]
# ### Store `update()` Method: Storing database docs
#
# Note: Updating stores requires read-write access

# %%
# check that your sandbox store is empty

# %%
# sandbox store is no longer empty

# %%
# let's try storing the 2 aneb docs from earlier
# must delete the unique doc identifier "_id" field first

# %%
# let's check that all docs are stored - expecting 1+2 docs

# %%
# we did not successfully store the 2 aneb docs
# the issue is we were missing unique values for the batt_id key field

# %%
# let's change to a more unique key field and try again

# %%
# let's check that all docs are stored - should get 3 docs now

# %% [markdown]
# ### Store `count()` Method

# %% [markdown]
# ### Store `distinct()` Method: Get distinct values of specified field

# %% [markdown]
# ### Store `remove_docs()` Method

# %% [markdown]
# ## Builder Basics: Convert "Source" Store to "Target" Store
#
# [copied from maggma's documentation...]
#
# Builders represent a data processing step. Builders break down each transformation into 3 phases: `get_items`, `process_item`, and `update_targets`:
#
# 1. `get_items`: Retrieve items from the source Store(s) for processing by the next phase
# 2. `process_item`: Manipulate the input item and create an output document that is sent to the next phase for storage.
# 3. `update_target`: Add the processed item to the target Store(s).

# %% [markdown]
# ### Getting a Builder
#
# Note: source collection only requires **read-only** access but the target collection requires **read-write** access

# %%
from maggma.builders.map_builder import MapBuilder, CopyBuilder

# %%
# for builders derived from MapBuilder, it is important to check the store keys
# MapBuilder relies on the key field for comparing docs in the source and target store
aneb_store.key = "wf_uuid"
sandbox_store.key = "wf_uuid"

# %%
query = {"batt_id":"spinelTi2S4_Mg"} # specify which docs from source store to grab
builder = CopyBuilder(source=aneb_store, target=sandbox_store, query=query)

# %%
aneb_store.count(query)

# %%
sandbox_store.count(query)

# %% [markdown]
# ### Builder `get_items()` Method
#
# The number of items should match the count from the source store above

# %%
items = builder.get_items()
print(len(items))

# %% [markdown]
# ### Builder `process_item()` Method

# %% [markdown]
# ### Builder `update_target()` Method

# %% [markdown]
# ### Running a Builder for Testing: `run()` Method

# %% [markdown]
# ## Writing a Custom Builder
#
# `MapBuilder` is very helpful when you want to perform the same action on documents from your source store. This can be accomplished by customizing the `unary_function()` method.
#
# https://github.com/materialsproject/maggma/blob/main/src/maggma/builders/map_builder.py#L208

# %%
class MyBuilder(MapBuilder):
    def unary_function(self,item):
        item_for_target = {"wf_uuid":item["wf_uuid"], # important to keep key field
                           "note":"development",
                           "bid":item["batt_id"] # let's try renaming the batt_id field
                          }
        return item_for_target

# %%
my_builder = MyBuilder(source=aneb_store, target=sandbox_store, query=query)

# %% [markdown]
# Before running our custom builder, we need to remove documents from our target store

# %%
print(sandbox_store.count(query))
sandbox_store.remove_docs(query)
print(sandbox_store.count(query))

# %%
my_builder.run()

# %%
print(sandbox_store.count(query))

# %% [markdown]
# # Onboarding Independent Exercises
#
# 1. How many total documents are in the `fw_acr_mv/approx_neb` collection?
#
# 2. How many unique `batt_id` values are there for documents in the `fw_acr_mv/approx_neb` collection? How many unique `wf_uuid` values?
#
# 3. Based on your answers to #1 and #2, what may be the best key field for the `fw_acr_mv/approx_neb` collection? Why?
#
# 4. Obtain the unique `tags` values that contain the string `"batch"`. Then, count the number of documents matching these tags values (e.g. 18 docs match "20191122_batch", 25 docs match "20191127_batch", etc.). (Hint: try the MongoDB query operators `"$in"` or `"$all"` for finding documents where a list contains a certain value: https://docs.mongodb.com/manual/reference/operator/query/)
#
# 5. Develop your own custom version of the MapBuilder and test out running it to check if it works as expected.

# %% [markdown]
# ### 1. How many total documents are in the `fw_acr_mv/approx_neb` collection?

# %% [markdown]
# ### 2. How many unique `batt_id` values are there for documents in the `fw_acr_mv/approx_neb` collection? How many unique `wf_uuid` values?

# %% [markdown]
# ### 3. Based on your answers to #1 and #2, what may be the best key field for the `fw_acr_mv/approx_neb` collection? Why?

# %% [markdown]
# There are some cases where multiple approx_neb docs have the same batt_id. There is a distinct wf_uuid value for every approx_neb doc so this is a better key field for distinguishing each doc as would be important for MapBuilder.
#
# However, the batt_id field may be a more appropriate key if we are interested in analysis for a given battery electrode. The best choice for key depends on the context.

# %% [markdown]
# ### 4. Obtain the unique `tags` values that contain the string `"batch"`. Then, count the number of documents matching these tags values (e.g. 18 docs match "20191122_batch", 25 docs match "20191127_batch", etc.).
#
# (Hint: try the MongoDB query operators `"$in"` or `"$all"` for finding documents where a list contains a certain value: https://docs.mongodb.com/manual/reference/operator/query/)

# %% [markdown]
# ### 5. Develop your own custom version of the MapBuilder and test out running it to check if it works as expected.
